# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/altocodigoPy/blob/main/piramide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 5

height = (n+1) // 2

for i in range(1, height + 1):
    stars = 2 * i - 1
    spaces = (n - stars) // 2
    print(" " * spaces + "$" * stars)
# Out:
#   $
#  $$$
# $$$$$
